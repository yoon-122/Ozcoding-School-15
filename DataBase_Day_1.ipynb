# %% [markdown]
# <a href="https://colab.research.google.com/github/yoon-122/Ozcoding-School-15/blob/main/DataBase_Day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [문제1]
# DBMS 특징이 아닌것을 골라주세요
#
# 	•	데이터 무경성
# 	•	데이터 보안성
# 	•	데이터 일관성
# 	•	데이터 의존성

# %% [markdown]
# 정답 : 데이터 의존성

# %% [markdown]
# ----

# %% [markdown]
# [문제2]
# 아래 설명에 해당하는 데이터 모델을 골라주세요
# 표 형태로 데이터를 저장하고 SQL을 사용하여 데이터를 조작합니다.
# 가장 널리 사용되는 데이터 모델 중 하나이며 RDBMS에서 지원합니다.
#
# 	•	관계형 데이터 모델
# 	•	객체 지향형 데이터 모델
# 	•	계층형 데이터 모델
# 	•	네트워크형 데이터 모델

# %% [markdown]
# 정답: 관계형 데이터 모델

# %% [markdown]
# ----

# %% [markdown]
# [문제3]
# 데이터베이스의 구조를 정의하는 것을 골라주세요
#
# 	•	인덱스
# 	•	트랜잭션
# 	•	스키마
# 	•	SQL

# %% [markdown]
# 	정답 : 스키마

# %% [markdown]
# ----

# %% [markdown]
# [문제4]
# RDBMS의 대표적인 단점이 아닌것을 골라주세요
#
# 	•	실시간 데이터 처리의 어려움
# 	•	운영 비용이 비쌈
# 	•	테이블 join의 복잡성
# 	•	미리 만들어진 스키마 구조를 변경 또는 확장하는데 어려움
# 	•	대량의 데이터를 저장하는게 어려움

# %% [markdown]
# 정답 :  대량의 데이터를 저장하는게 어려움

# %% [markdown]
# ----

# %% [markdown]
# [문제5]
# RDBMS의 구성 요소 중 고유한 값을 나타내는 것을 골라주세요
#
# 	•	column
# 	•	row
# 	•	FK
# 	•	PK

# %% [markdown]
# 정답 : PK

# %% [markdown]
# ----

# %% [markdown]
# [문제6]
# 대표적인 RDBMS가 아닌것을 골라주세요
#
# 	•	SQLite
# 	•	Oracle Database
# 	•	PostgreSQL
# 	•	Firebase

# %% [markdown]
# 정답 : Firebase

# %% [markdown]
# ----

# %% [markdown]
# [문제7]
# 물리적 스키마란 무엇을 의마하는지 골라주세요
#
# 	•	데이터베이스 논리적 구조
# 	•	데이터베이스 물리적 저장 방식
# 	•	데이터베이스 사용자 뷰
# 	•	데이터베이스의 엑세스 권한

# %% [markdown]
# 정답 : 데이터베이스 물리적 저장 방식

# %% [markdown]
# ----

# %% [markdown]
# [문제8]
# SQL 언어에 해당하지 않는 것을 골라주세요
#
# 	•	데이터 처리 언어(DML)
# 	•	데이터 제어 언어(DCL)
# 	•	데이터 연결 언어(DCL)
# 	•	데이터 정의 언어(DDL)

# %% [markdown]
# 	정답 : 데이터 연결 언어(DCL)

# %% [markdown]
# ----

# %% [markdown]
# [문제9]
# 데이터 처리 언어(DML)의 설명으로 틀린것을 골라주세요
#
# 	•	select : 데이터베이스에서 정보를 검색
# 	•	insert : 새로운 데이터를 테이블에 삽입
# 	•	count : 테이블의 데이터 개수 확인
# 	•	delete : 테이블에서 데이터를 삭제

# %% [markdown]
# 정답 : count

# %% [markdown]
# ----

# %% [markdown]
# [문제10]
# 데이터 제어 언어(DCL)인 GRANT에 대한 설명으로 옳은 것을 골라주세요
#
# 	•	사용자에게 특정 작업을 수행할 권한을 부여한다.
# 	•	사용자로부터 특정 작업 수행 권항을 제거한다.
# 	•	다른 사용자에게 동일한 권한을 전달할때 사용한다.
# 	•	부여된 권한 중 일부를 제한할때 사용한다.

# %% [markdown]
# 정답 : 사용자에게 특정 작업을 수행할 권한을 부여한다.

# %% [markdown]
# ----
